# %% [markdown]
# # Datos censales

# %% [markdown]
# En este notebook, se tomarán las bases de datos de los censos correspondientes a los años 2017 y 2024. Se juntarpan por comuna, y se interpolarán para hacer una estimación de la población aproximada durante los años intermedios.

# %%
import pandas as pd

# %%
# Función para manejar los nombres de las comunas

def limpiar_comuna(nombre):
    nombre = nombre.strip().title()
    nombre = nombre.replace('Nunoa', 'Ñuñoa')
    nombre = nombre.replace('Penalolen', 'Peñalolén')
    nombre = nombre.replace('Peñalolen', 'Peñalolén')
    nombre = nombre.replace('Conchali', 'Conchalí')
    nombre = nombre.replace('Estacion Central', 'Estación Central')
    nombre = nombre.replace('San Joaquin', 'San Joaquín')
    nombre = nombre.replace('San Jose De Maipo', 'San José de Maipo')
    nombre = nombre.replace('San Ramon', 'San Ramón')
    nombre = nombre.replace('Maipu', 'Maipú')
    nombre = nombre.replace('Alhue', 'Alhué')
    nombre = nombre.replace('Curacavi', 'Curacaví')
    if 'Desconocido' in nombre or 'Total' in nombre:
        return None
    return nombre

# %% [markdown]
# # Base de datos 2017

# %%
df_2017 = pd.read_excel('Poblacion-censada-y-residentes-habituales-Censo-2017.xlsx', sheet_name=2, header=3)
df_2017.reset_index(drop=True, inplace=True)
df_2017.head()
# Out:
#   Código región    Región  Código provincia      Provincia  Código comuna  \
# 0             0      País               0.0           País            0.0
# 1             1  Tarapacá              11.0        Iquique         1101.0
# 2             1  Tarapacá              11.0        Iquique         1107.0
# 3             1  Tarapacá              14.0  Del Tamarugal         1401.0
# 4             1  Tarapacá              14.0  Del Tamarugal         1402.0
#
#           Comuna  Población censada  Residentes habituales
# 0           País         17574003.0             17327192.0
# 1        Iquique           191468.0               191824.0
# 2  Alto Hospicio           108375.0               106596.0
# 3   Pozo Almonte            15711.0                13942.0
# 4         Camiña             1250.0                 1217.0

# %%
# Filtramos para la región metropolitana

df_2017 = df_2017[df_2017['Región'] == 'Metropolitana De Santiago']
df_2017 = df_2017.reset_index(drop=True)
df_2017.head()
# Out:
#   Código región                     Región  Código provincia Provincia  \
# 0            13  Metropolitana De Santiago             131.0  Santiago
# 1            13  Metropolitana De Santiago             131.0  Santiago
# 2            13  Metropolitana De Santiago             131.0  Santiago
# 3            13  Metropolitana De Santiago             131.0  Santiago
# 4            13  Metropolitana De Santiago             131.0  Santiago
#
#    Código comuna       Comuna  Población censada  Residentes habituales
# 0        13101.0     Santiago           404495.0               411183.0
# 1        13102.0    Cerrillos            80832.0                79842.0
# 2        13103.0  Cerro Navia           132622.0               131433.0
# 3        13104.0     Conchalí           126955.0               125278.0
# 4        13105.0    El Bosque           162505.0               161571.0

# %%
df_2017 = df_2017[['Comuna', 'Residentes habituales']].copy()
df_2017.rename(columns={'Residentes habituales': 'Población 2017'}, inplace=True)
df_2017.reset_index(drop=True, inplace=True)
df_2017.head()
# Out:
#         Comuna  Población 2017
# 0     Santiago        411183.0
# 1    Cerrillos         79842.0
# 2  Cerro Navia        131433.0
# 3     Conchalí        125278.0
# 4    El Bosque        161571.0

# %% [markdown]
# # Base de datos 2024

# %%
df_2024 = pd.read_excel('D1_Poblacion-censada-por-sexo-y-edad-en-grupos-quinquenales.xlsx', sheet_name=2, header=3)
df_2024.reset_index(drop=True, inplace=True)
df_2024.head()
# Out:
#   Código región              Región  Código provincia   Provincia  \
# 0             0                País               0.0        País
# 1            15  Arica y Parinacota             151.0       Arica
# 2            15  Arica y Parinacota             151.0       Arica
# 3            15  Arica y Parinacota             152.0  Parinacota
# 4            15  Arica y Parinacota             152.0  Parinacota
#
#    Código comuna         Comuna  Población censada    Hombres    Mujeres  \
# 0            0.0           País         18480432.0  8967033.0  9513399.0
# 1        15101.0          Arica           241653.0   118844.0   122809.0
# 2        15102.0      Camarones              861.0      430.0      431.0
# 3        15201.0          Putre             1547.0      846.0      701.0
# 4        15202.0  General Lagos              508.0      261.0      247.0
#
#    Razón hombre-mujer
# 0                94.3
# 1                96.8
# 2                99.8
# 3               120.7
# 4               105.7

# %%
df_2024 = df_2024[df_2024['Región'] == 'Metropolitana de Santiago']
df_2024 = df_2024.reset_index(drop=True)
df_2024.head()
# Out:
#   Código región                     Región  Código provincia Provincia  \
# 0            13  Metropolitana de Santiago             131.0  Santiago
# 1            13  Metropolitana de Santiago             131.0  Santiago
# 2            13  Metropolitana de Santiago             131.0  Santiago
# 3            13  Metropolitana de Santiago             131.0  Santiago
# 4            13  Metropolitana de Santiago             131.0  Santiago
#
#    Código comuna       Comuna  Población censada   Hombres   Mujeres  \
# 0        13101.0     Santiago           438856.0  223237.0  215619.0
# 1        13102.0    Cerrillos            85041.0   41216.0   43825.0
# 2        13103.0  Cerro Navia           127250.0   62329.0   64921.0
# 3        13104.0     Conchalí           121587.0   59122.0   62465.0
# 4        13105.0    El Bosque           155257.0   75720.0   79537.0
#
#    Razón hombre-mujer
# 0               103.5
# 1                94.0
# 2                96.0
# 3                94.6
# 4                95.2

# %%
df_2024 = df_2024[['Comuna', 'Población censada']].copy()
df_2024['Comuna'] = df_2024['Comuna'].apply(limpiar_comuna)
df_2024.rename(columns={'Población censada': 'Población 2024'}, inplace=True)
df_2024.head()
# Out:
#         Comuna  Población 2024
# 0     Santiago        438856.0
# 1    Cerrillos         85041.0
# 2  Cerro Navia        127250.0
# 3     Conchalí        121587.0
# 4    El Bosque        155257.0

# %% [markdown]
# # Merge censo 2017 - 2024

# %%
df_censo = pd.merge(df_2017, df_2024, on='Comuna', how='inner')
df_censo
# Out:
#                  Comuna  Población 2017  Población 2024
# 0              Santiago        411183.0        438856.0
# 1             Cerrillos         79842.0         85041.0
# 2           Cerro Navia        131433.0        127250.0
# 3              Conchalí        125278.0        121587.0
# 4             El Bosque        161571.0        155257.0
# 5      Estación Central        139257.0        181049.0
# 6            Huechuraba         97829.0        101808.0
# 7         Independencia         98513.0        116943.0
# 8           La Cisterna         89204.0        103157.0
# 9            La Florida        364039.0        374836.0
# 10            La Granja        115641.0        112022.0
# 11           La Pintana        176188.0        175421.0
# 12             La Reina         91717.0         89870.0
# 13           Las Condes        287023.0        296134.0
# 14         Lo Barnechea        103301.0        112620.0
# 15            Lo Espejo         98025.0         87295.0
# 16             Lo Prado         95325.0         91290.0
# 17                Macul        115802.0        123800.0
# 18                Maipú        517384.0        503635.0
# 19                Ñuñoa        205602.0        241467.0
# 20  Pedro Aguirre Cerda        100036.0         96062.0
# 21            Peñalolén        239615.0        236478.0
# 22          Providencia        136279.0        143974.0
# 23             Pudahuel        225447.0        227820.0
# 24            Quilicura        208460.0        205624.0
# 25        Quinta Normal        109456.0        129351.0
# 26             Recoleta        155779.0        154615.0
# 27                Renca        145359.0        143622.0
# 28          San Joaquín         93710.0         95602.0
# 29           San Miguel        105879.0        150829.0
# 30            San Ramón         81817.0         76002.0
# 31             Vitacura         82858.0         86420.0
# 32          Puente Alto        562136.0        568086.0
# 33               Pirque         26217.0         29060.0
# 34               Colina        143674.0        173293.0
# 35                Lampa        100785.0        145160.0
# 36               Tiltil         18769.0         19742.0
# 37         San Bernardo        298699.0        306371.0
# 38                 Buin         95653.0        116969.0
# 39      Calera De Tango         25230.0         25491.0
# 40                Paine         71872.0         78828.0
# 41            Melipilla        122274.0        136325.0
# 42                Alhué          6007.0          7768.0
# 43             Curacaví         32068.0         35165.0
# 44          María Pinto         13341.0         15352.0
# 45            San Pedro         10156.0         11108.0
# 46            Talagante         73234.0         76429.0
# 47             El Monte         35552.0         37497.0
# 48        Padre Hurtado         62601.0         81243.0
# 49             Peñaflor         89419.0         94402.0

# %% [markdown]
# Para ver si estos datos tienen sentido, hagamos la suma por columnas a ambos años:

# %%
# Sumar la columna de población 2017
total_2017 = df_censo['Población 2017'].sum()
print(f"Población total 2017 RM: {total_2017:,.0f}")

# Sumar la columna de población 2024
total_2024 = df_censo['Población 2024'].sum()
print(f"Población total 2024 RM: {total_2024:,.0f}")
# Out:
# Población total 2017 RM: 6,976,539
# Población total 2024 RM: 7,344,026

# %% [markdown]
# # Interpolación: estimación de habitantes por comuna entre el período 2017-2024

# %%
anios = list(range(2017, 2025)) 
comunas = df_censo['Comuna']

filas = []

for index, fila in df_censo.iterrows():
    pob_2017 = fila['Población 2017']
    pob_2024 = fila['Población 2024']
    # Interpolación lineal para cada año
    for j, año in enumerate(anios):
        pob_interp = pob_2017 + (pob_2024 - pob_2017) * j / (2024 - 2017)
        filas.append({'Comuna': fila['Comuna'], 'Año': año, 'Población': pob_interp})

print(filas)
# Out:
# [{'Comuna': 'Santiago', 'Año': 2017, 'Población': 411183.0}, {'Comuna': 'Santiago', 'Año': 2018, 'Población': 415136.28571428574}, {'Comuna': 'Santiago', 'Año': 2019, 'Población': 419089.5714285714}, {'Comuna': 'Santiago', 'Año': 2020, 'Población': 423042.85714285716}, {'Comuna': 'Santiago', 'Año': 2021, 'Población': 426996.14285714284}, {'Comuna': 'Santiago', 'Año': 2022, 'Población': 430949.4285714286}, {'Comuna': 'Santiago', 'Año': 2023, 'Población': 434902.71428571426}, {'Comuna': 'Santiago', 'Año': 2024, 'Población': 438856.0}, {'Comuna': 'Cerrillos', 'Año': 2017, 'Población': 79842.0}, {'Comuna': 'Cerrillos', 'Año': 2018, 'Población': 80584.71428571429}, {'Comuna': 'Cerrillos', 'Año': 2019, 'Población': 81327.42857142857}, {'Comuna': 'Cerrillos', 'Año': 2020, 'Población': 82070.14285714286}, {'Comuna': 'Cerrillos', 'Año': 2021, 'Población': 82812.85714285714}, {'Comuna': 'Cerrillos', 'Año': 2022, 'Población': 83555.57142857143}, {'Comuna': 'Cerrillos', 'Año': 2023, 'Población': 84298.28571428571}, {'Comuna': 'Cerrillos', 'Año': 2024, 'Población': 85041.0}, {'Comuna': 'Cerro Navia', 'Año': 2017, 'Población': 131433.0}, {'Comuna': 'Cerro Navia', 'Año': 2018, 'Población': 130835.42857142857}, {'Comuna': 'Cerro Navia', 'Año': 2019, 'Población': 130237.85714285714}, {'Comuna': 'Cerro Navia', 'Año': 2020, 'Población': 129640.28571428571}, {'Comuna': 'Cerro Navia', 'Año': 2021, 'Población': 129042.71428571429}, {'Comuna': 'Cerro Navia', 'Año': 2022, 'Población': 128445.14285714286}, {'Comuna': 'Cerro Navia', 'Año': 2023, 'Población': 127847.57142857143}, {'Comuna': 'Cerro Navia', 'Año': 2024, 'Población': 127250.0}, {'Comuna': 'Conchalí', 'Año': 2017, 'Población': 125278.0}, {'Comuna': 'Conchalí', 'Año': 2018, 'Población': 124750.71428571429}, {'Comuna': 'Conchalí', 'Año': 2019, 'Población': 124223.42857142857}, {'Comuna': 'Conchalí', 'Año': 2020, 'Población': 123696.14285714286}, {'Comuna': 'Conchalí', 'Año': 2021, 'Población': 123168.85714285714}, {'Comuna': 'Conchalí', 'Año': 2022, 'Población': 122641.57142857143}, {'Comuna': 'Conchalí', 'Año': 2023, 'Población': 122114.28571428571}, {'Comuna': 'Conchalí', 'Año': 2024, 'Población': 121587.0}, {'Comuna': 'El Bosque', 'Año': 2017, 'Población': 161571.0}, {'Comuna': 'El Bosque', 'Año': 2018, 'Población': 160669.0}, {'Comuna': 'El Bosque', 'Año': 2019, 'Población': 159767.0}, {'Comuna': 'El Bosque', 'Año': 2020, 'Población': 158865.0}, {'Comuna': 'El Bosque', 'Año': 2021, 'Población': 157963.0}, {'Comuna': 'El Bosque', 'Año': 2022, 'Población': 157061.0}, {'Comuna': 'El Bosque', 'Año': 2023, 'Población': 156159.0}, {'Comuna': 'El Bosque', 'Año': 2024, 'Población': 155257.0}, {'Comuna': 'Estación Central', 'Año': 2017, 'Población': 139257.0}, {'Comuna': 'Estación Central', 'Año': 2018, 'Población': 145227.2857142857}, {'Comuna': 'Estación Central', 'Año': 2019, 'Población': 151197.57142857142}, {'Comuna': 'Estación Central', 'Año': 2020, 'Población': 157167.85714285713}, {'Comuna': 'Estación Central', 'Año': 2021, 'Población': 163138.14285714287}, {'Comuna': 'Estación Central', 'Año': 2022, 'Población': 169108.42857142858}, {'Comuna': 'Estación Central', 'Año': 2023, 'Población': 175078.7142857143}, {'Comuna': 'Estación Central', 'Año': 2024, 'Población': 181049.0}, {'Comuna': 'Huechuraba', 'Año': 2017, 'Población': 97829.0}, {'Comuna': 'Huechuraba', 'Año': 2018, 'Población': 98397.42857142857}, {'Comuna': 'Huechuraba', 'Año': 2019, 'Población': 98965.85714285714}, {'Comuna': 'Huechuraba', 'Año': 2020, 'Población': 99534.28571428571}, {'Comuna': 'Huechuraba', 'Año': 2021, 'Población': 100102.71428571429}, {'Comuna': 'Huechuraba', 'Año': 2022, 'Población': 100671.14285714286}, {'Comuna': 'Huechuraba', 'Año': 2023, 'Población': 101239.57142857143}, {'Comuna': 'Huechuraba', 'Año': 2024, 'Población': 101808.0}, {'Comuna': 'Independencia', 'Año': 2017, 'Población': 98513.0}, {'Comuna': 'Independencia', 'Año': 2018, 'Población': 101145.85714285714}, {'Comuna': 'Independencia', 'Año': 2 ...

# %%
# Luego de crear la función para la interpolación de datos, lo ponemos en un DataFrame

df_interpolado = pd.DataFrame(filas)
df_interpolado.head()
# Out:
#      Comuna   Año      Población
# 0  Santiago  2017  411183.000000
# 1  Santiago  2018  415136.285714
# 2  Santiago  2019  419089.571429
# 3  Santiago  2020  423042.857143
# 4  Santiago  2021  426996.142857

# %%
df_interpolado.to_csv('estimacion_poblacion_por_comunas.csv', index=False)
